# %% [markdown]
# # CIFAR-10 CNN
#
# CIFAR-10: https://www.cs.toronto.edu/~kriz/cifar.html
#
# O conjunto de dados CIFAR-10 possui 60.000 imagens coloridas de dimensões $32\times 32$. Os dados são divididos em 10 casses com 6.000 imagens por classe.
#
# O exemplo abaixo é uma adaptação do exemplo fornecido na documentação do Keras:
# https://github.com/fchollet/keras/blob/master/examples/cifar10_cnn.py Nele, nós utilizamos apenas 3 das 10 classes. A saída das diferentes camadas da CNN são mostradas.

# %%
# !nvidia-smi
# Out:
# Wed Feb 22 13:33:58 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 367.57                 Driver Version: 367.57                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GRID K520           On   | 0000:00:03.0     Off |                  N/A |
# | N/A   40C    P8    17W / 125W |     99MiB /  4036MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Importando as bibliotecas

# %%
#Importando as bibliotecas necessárias
# %matplotlib inline
import numpy as np
import sys
np.random.seed(1337)  # for reproducibility
import matplotlib.pylab as plt
import os
os.environ['THEANO_FLAGS'] = "device=gpu0,floatX=float32"
from keras.datasets import cifar10
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils
from keras.optimizers import SGD
import numpy as np
import cv2
import theano

# %% [markdown]
# ## Carregando e mostrando os dados

# %%
nb_classes = 3 #Número de classes

# Carregando os dados
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
y_train = y_train.ravel()
y_test = y_test.ravel()


#Selecionando apenas objetos das classes: 0, 1, 2
indexes_train = (y_train == 0) | (y_train == 1) | (y_train == 2)
X_train = X_train[indexes_train].mean(axis=1,keepdims = True) #RGB para cinza
y_train = y_train[indexes_train]

indexes_test = (y_test == 0) | (y_test == 1) | (y_test == 2) 
X_test = X_test[indexes_test].mean(axis=1,keepdims = True) #RGB para cinza
y_test = y_test[indexes_test]

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'amostras de treinamento')
print(X_test.shape[0], 'amostras de teste')

#Mostrando algumas imagens do conjunto de teste
plt.figure(figsize=(24, 12))

for k, i in enumerate(np.random.choice(np.arange(0, len(y_test)), size=(40,))):
    plt.subplot(5, 8, k + 1)
    image = (X_test[i])
    image = cv2.resize(image[0], (96, 96), interpolation=cv2.INTER_LINEAR)
    
    # mostra as imagens
    plt.imshow(image,cmap = 'gray')
    plt.axis('off')
    
# Transforma o vetor de labes para o formato de one-hot encoding.
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

#Normalização dos dados
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
# Out:
# ('X_train shape:', (15000, 1, 32, 32))
# (15000, 'amostras de treinamento')
# (3000, 'amostras de teste')

# %% [markdown]
# # Construíndo a CNN com o Keras

# %%
def model_build():
    batch_size = 100
    nb_epoch = 25 # Numero de épocas
    img_rows, img_cols = 32, 32 # Dimensões das imagens
    input_shape = (1, img_rows, img_cols)

    # Definindo a rede
    model = Sequential()
    model.add(Convolution2D(32, 3, 3,
                            border_mode='valid',
                            input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Convolution2D(32,3,3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    # Aqui os features deixam de ser imagens
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    return model

# %%
def model_build_dense():
    batch_size = 600
    nb_epoch = 35 # Numero de épocas
    img_rows, img_cols = 32, 32 # Dimensões das imagens
    input_shape = (1, img_rows, img_cols)

    # Definindo a rede
    model = Sequential()

    # Definindo a rede
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense((img_rows-2)*(img_cols-2)*32))
    model.add(Activation('relu'))
    model.add(Dense((img_rows-4)*(img_cols-4)*32))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    # Aqui os features deixam de ser imagens
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    return model

# %%
nepochs = 70
ploss = 1.0
sys.path.append("../src")
from my_keras_utilities import TrainingPlotter, load_model_and_history
#model_name = './cifar_11'

#if not os.path.isfile(model_name + '.model'):
print("[INFO] creating model...")
#model = model_build()
model = model_build_dense()
# History, checkpoint, earlystop, plot losses:
my_big_callback = TrainingPlotter(n=1, filepath=model_name, patience=15)

# initialize the optimizer and model
print("[INFO] compiling model...")
opt = SGD(lr=0.01, momentum=0.9)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])    
    
# else:
#     print("[INFO] loading model...")
#     model, my_big_callback = load_model_and_history(model_name)

past_epochs = my_big_callback.get_nepochs()

fig = plt.figure(figsize=(15,6))
plt.ylim(0.0, ploss)
plt.xlim(0, nepochs)
plt.grid(True)

print("[INFO] training...")
try:
    histo2 = model.fit(X_train, Y_train, batch_size=128, nb_epoch=nepochs - past_epochs, 
                       verbose=0, validation_split=0.33, callbacks=[my_big_callback])
except KeyboardInterrupt:
    pass

print("[INFO] evaluating...")
loss, accuracy = model.evaluate(X_test, Y_test, batch_size=128, verbose=1)
print("[INFO] accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# [INFO] creating model...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-72-98d3323899fb> in <module>()
#       8 print("[INFO] creating model...")
#       9 #model = model_build()
# ---> 10 model = model_build_dense()
#      11 # History, checkpoint, earlystop, plot losses:
#      12 my_big_callback = TrainingPlotter(n=1, filepath=model_name, patience=15)
#
# <ipython-input-71-7525e95debff> in model_build_dense()
#      13     model.add(Dense((img_rows-2)*(img_cols-2)*32))
#      14     model.add(Activation('relu'))
# ---> 15     model.add(Dense((img_rows-4)*(img_cols-4)*32))
#      16     model.add(Activation('relu'))
#      17     model.add(Dropout(0.25))
#
# /opt/conda/lib/python2.7/site-packages/keras/models.pyc in add(self, layer)
#     325                  output_shapes=[self.outputs[0]._keras_shape])
#     326         else:
# --> 327             output_tensor = layer(self.outputs[0])
#     328             if isinstance(output_tensor, list):
#     329                 raise TypeError('All layers in a Sequential model '
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/topology.pyc in __call__(self, x, mask)
#     541                                      '`layer.build(batch_input_shape)`')
#     542             if len(input_shapes) == 1:
# --> 543                 self.build(input_shapes[0])
#     544             else:
#     545                 self.build(input_shapes)
#
# /opt/conda/lib/python2.7/site-packages/keras/layers/core.pyc in build(self, input_shape)
#     750                                  name='{}_W'.format(self.name),
#     751                                  regularizer=self.W_regularizer,
# --> 752                                  constraint=self.W_constraint)
#     753         if self.bias:
#     754             self.b = self.add_weight((self.output_dim,),
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/topology.pyc in add_weight(self, shape, initializer, name, trainable, regularizer, constraint)
#     413         '''
#     414         initializer = initializations.get(initializer)
# --> 415         weight = initializer(shape, name=name)
#     416         if regularizer is not None:
#     417             self.add_loss(regularizer(weight))
#
# /opt/conda/lib/python2.7/site-packages/keras/initializations.pyc in glorot_uniform(shape, name, dim_ordering)
#      58     fan_in, fan_out = get_fans(shape, dim_ordering=dim_ordering)
#      59     s = np.sqrt(6. / (fan_in + fan_out))
# ---> 60     return uniform(shape, s, name=name)
#      61
#      62
#
# /opt/conda/lib/python2.7/site-packages/keras/initializations.pyc in uniform(shape, scale, name)
#      31
#      32 def uniform(shape, scale=0.05, name=None):
# ---> 33     return K.random_uniform_variable(shape, -scale, scale, name=name)
#      34
#      35
#
# /opt/conda/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in random_uniform_variable(shape, low, high, dtype, name)
#     177 def random_uniform_variable(shape, low, high, dtype=None, name=None):
#     178     return variable(np.random.uniform(low=low, high=high, size=shape),
# --> 179                     dtype=dtype, name=name)
#     180
#     181
#
# /opt/conda/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in variable(value, dtype, name)
#      75     else:
#      76         value = np.asarray(value, dtype=dtype)
# ---> 77         variable = theano.shared(value=value, name=name, strict=False)
#      78     variable._keras_shape = value.shape
#      79     variable._uses_learning_phase = False
#
# /opt/conda/lib/python2.7/site-packages/theano/compile/sharedvalue.pyc in shared(value, name, strict, allow_downcast, **kwargs)
#     245             try:
#     246                 var = ctor(value, name=name, strict=strict,
# --> 247                            allow_downcast=allow_downcast, **kwargs)
#     248                 utils.add_tag_trace(var)
#     249                 return var
#
# /opt/conda/lib/python2.7/site-packages/theano/sandbox/cuda/var.pyc in float32_shared_constructor(value, name, strict, allow_downcast, borrow, broadcastable, target)
#     238         # type.broadcastable is guaranteed to be a tuple, which this next
#     239         # function requires
# --> 240         deviceval = type_support_filter(value, type.broadcastable, False, None)
#     241
#     242     try:
#
# MemoryError: ('Error allocating 2890137600 bytes of device memory (out of memory).', "you might consider using 'theano.shared(..., borrow=True)'")

# %%
#Função que desenha o mosaico
def mosaic(f,N):
    d,h,w = f.shape
    nLines = np.ceil(float(d)/N)
    nCells = nLines*N
        
    fullf = np.resize(f, (nCells,h,w))
    fullf[d:nCells,:,:] = 0        
        
    Y,X = np.indices((nLines*h,N*w))
    Pts = np.array([
                   (np.floor(Y/h)*N + np.floor(X/w)).ravel(),
                   np.mod(Y,h).ravel(),
                   np.mod(X,w).ravel() ]).astype(int).reshape((3,int(nLines*h),int(N*w)))
    g = fullf[Pts[0],Pts[1],Pts[2]]
    return g

# %%
sn = 0
plt.figure()
plt.imshow(X_test[sn,0,:,:],cmap = 'gray')
plt.axis('off')
plt.title("Original")
ncols = 8
H,W = 10,30

model.summary()

#Mostrando a saida das camadas convolucionais
for layer in model.layers[0:5]:
    intermediate_layer_model = Model(input=model.input,output=layer.output)
    intermediate_output = intermediate_layer_model.predict(X_test[sn].reshape(1,1,32,32))
    sub_dim = intermediate_output.shape[1]
    name = str(layer).split('.')[3].split(" ")[0]
    if name =="MaxPooling2D":
        H = H/2
        W = W/2
    fig =plt.figure(figsize=(H,W))
    aux = intermediate_output[0,:,:,:]
    mos = mosaic(aux,ncols)
    plt.imshow(mos,cmap = 'gray')
    plt.axis('off')
    plt.title(name)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# flatten_11 (Flatten)             (None, 1024)          0           flatten_input_2[0][0]
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 256)           262400      flatten_11[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 256)           0           dense_22[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 256)           0           activation_24[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 256)           65792       dropout_13[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 256)           0           dense_23[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 256)           0           activation_25[0][0]
# ____________________________________________________________________________________________________
# dense_24 (Dense)                 (None, 3)             771         dropout_14[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 3)             0           dense_24[0][0]
# ====================================================================================================
# Total params: 328,963
# Trainable params: 328,963
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-a73510aa61d7> in <module>()
#      19         W = W/2
#      20     fig =plt.figure(figsize=(H,W))
# ---> 21     aux = intermediate_output[0,:,:,:]
#      22     mos = mosaic(aux,ncols)
#      23     plt.imshow(mos,cmap = 'gray')
#
# IndexError: too many indices for array

# %% [markdown]
# ## Atividades
#
# 1. Quantos parâmetros são treinados nesta rede? Calcule o número de parâmetros de cada camada, não se esquecendo do *bias*. Confira o valor calculado com o `summary` do Keras.

# %% [markdown]
# ## Aprendizados com este experimento
#
# Atividade:
# ```py
# model.add(Convolution2D(32, 3, 3,
#     border_mode='valid',
#     input_shape=input_shape)) # 32 x 3 x 3 + 32 = 320
# model.add(Activation('relu'))
# model.add(Convolution2D(32,3,3)) # 32 x 32 x 3 x 3 + 32 = 9248
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.25))
#
# # Aqui os features deixam de ser imagens
# model.add(Flatten())
# model.add(Dense(128)) # 32 x 14 x 14 x 128 + 128 [border_mode = 'valid' diminuiu o tamanho + maxpooling]
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(Dense(nb_classes)) # 128 * 3 + 3 = 38
# model.add(Activation('softmax'))
# ```
#
# - A convnet está retirando os atributos e a rede densa classificando
# - Utilizar uma rede densa estoura memória no mesmo problema, então não teria como ser aplicada apropriadamente
